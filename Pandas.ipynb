# %% [markdown]
# # First Project with Pandas
#
# Looking at a spreadsheet I made, I was soon curious how I could make the table in Pandas and soon wanted to take the opportunity to put my first project in the portfolio.
# Feel free to evaluate or recommend improvement materials. : D

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from IPython.display import HTML
print("Setup Complete")
# Out:
# Setup Complete

# %%
#Creating DataFrame

book_list = ({'Book': ['Art of War', 'The old man and the sea', 'The Hobbit', '1984', 'Fausto', 'The Chronicles of Narnia', 'The little pince', 'The 48 Laws of Power', 'Freud for beginners'],
              'Author': ['Sun Tzu', 'Ernest Hemingway','J. R. R. Tolkien', 'George Orwell', 'Goethe','C.S. Lewis', 'Antione de Saint-Exupéry', 'Robert Greene', 'Richard Osborne'],
             'Finished': [2016, 2021, 2018, 2021, 2018, 2018, 2020, 2018, 2016], 'Purchased': [False,False,True,False,True,True,False,True,True],
              'Midia': ['eBook', 'Audiobook', 'eBook', 'Audiobook', 'eBook', 'eBook', 'Audiobook', 'Book', 'Book']}) 

pd.DataFrame(book_list)

#df = pd.DataFrame(book_list)   
#df.to_csv(index=False)
# Out:
# 'Book,Author,Finished,Purchased,Midia\nArt of War,Sun Tzu,2016,False,eBook\nThe old man and the sea,Ernest Hemingway,2021,False,Audiobook\nThe Hobbit,J. R. R. Tolkien,2018,True,eBook\n1984,George Orwell,2021,False,Audiobook\nFausto,Goethe,2018,True,eBook\nThe Chronicles of Narnia,C.S. Lewis,2018,True,eBook\nThe little pince,Antione de Saint-Exupéry,2020,False,Audiobook\nThe 48 Laws of Power,Robert Greene,2018,True,Book\nFreud for beginners,Richard Osborne,2016,True,Book\n'

# %%
# hide columns
books.head(10).style.hide_index().hide_columns(['Finished', 'Midia'])
# Out:
# <style  type="text/css" >
# </style><table id="T_a1efc_" ><thead>    <tr>        <th class="col_heading level0 col0" >Book</th>        <th class="col_heading level0 col1" >Author</th>        <th class="col_heading level0 col3" >Purchased</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a1efc_row0_col0" class="data row0 col0" >Art of War</td>
#                         <td id="T_a1efc_row0_col1" class="data row0 col1" >Sun Tzu</td>
#                                 <td id="T_a1efc_row0_col3" class="data row0 col3" >False</td>
#                     </tr>
#             <tr>
#                                 <td id="T_a1efc_row1_col0" class="data row1 col0" > The old man and the sea</td>
#                         <td id="T_a1efc_row1_col1" class="data row1 col1" >Ernest Hemingway</td>
#                                 <td id="T_a1efc_row1_col3" class="data row1 col3" >False</td>
#                     </tr>
#             <tr>
# ...

# %%
book_data = '../input/bookdata/book.csv'
books = pd.read_csv(book_data)
books.head(10)
# Out:
#                        Book                    Author  Finished  Purchased  \
# 0                Art of War                   Sun Tzu      2016      False
# 1   The old man and the sea          Ernest Hemingway      2021      False
# 2                The Hobbit          J. R. R. Tolkien      2018       True
# 3                      1984             George Orwell      2021      False
# 4                    Fausto                    Goethe      2018       True
# 5  The Chronicles of Narnia                C.S. Lewis      2018       True
# 6          The little pince  Antione de Saint-Exup�ry      2020      False
# 7      The 48 Laws of Power             Robert Greene      2018       True
# 8       Freud for beginners           Richard Osborne      2016       True
#
#        Midia
# 0      eBook
# 1  Audiobook
# 2      eBook
# 3  Audiobook
# 4      eBook
# 5      eBook
# 6  Audiobook
# 7       Book
# 8       Book

# %%
# select rows containing Purchased True
books.filter([2, 4, 5, 7,8], axis=0)
# Out:
#                        Book            Author  Finished  Purchased  Midia
# 2                The Hobbit  J. R. R. Tolkien      2018       True  eBook
# 4                    Fausto            Goethe      2018       True  eBook
# 5  The Chronicles of Narnia        C.S. Lewis      2018       True  eBook
# 7      The 48 Laws of Power     Robert Greene      2018       True   Book
# 8       Freud for beginners   Richard Osborne      2016       True   Book

# %%
#Testing colors for the table
books.head(10).style.set_properties(**{'background-color': '#ADD8E6', 'color': 'black', 'border-color': '#B2FFA8'})
# Out:
# <style  type="text/css" >
# #T_ca770_row0_col0,#T_ca770_row0_col1,#T_ca770_row0_col2,#T_ca770_row0_col3,#T_ca770_row0_col4,#T_ca770_row1_col0,#T_ca770_row1_col1,#T_ca770_row1_col2,#T_ca770_row1_col3,#T_ca770_row1_col4,#T_ca770_row2_col0,#T_ca770_row2_col1,#T_ca770_row2_col2,#T_ca770_row2_col3,#T_ca770_row2_col4,#T_ca770_row3_col0,#T_ca770_row3_col1,#T_ca770_row3_col2,#T_ca770_row3_col3,#T_ca770_row3_col4,#T_ca770_row4_col0,#T_ca770_row4_col1,#T_ca770_row4_col2,#T_ca770_row4_col3,#T_ca770_row4_col4,#T_ca770_row5_col0,#T_ca770_row5_col1,#T_ca770_row5_col2,#T_ca770_row5_col3,#T_ca770_row5_col4,#T_ca770_row6_col0,#T_ca770_row6_col1,#T_ca770_row6_col2,#T_ca770_row6_col3,#T_ca770_row6_col4,#T_ca770_row7_col0,#T_ca770_row7_col1,#T_ca770_row7_col2,#T_ca770_row7_col3,#T_ca770_row7_col4,#T_ca770_row8_col0,#T_ca770_row8_col1,#T_ca770_row8_col2,#T_ca770_row8_col3,#T_ca770_row8_col4{
#             background-color:  #ADD8E6;
#             color:  black;
#             border-color:  #B2FFA8;
# ...
